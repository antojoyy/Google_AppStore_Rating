# %% [markdown]
# ### Assignment
# ### PART I:

# %% [markdown]
# ### 1. Import required libraries and read the dataset.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("Apps_data.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %% [markdown]
# ### 2.Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.sample(10)
# Out:
#                                                App            Category  \
# 9793                              ES File Explorer               TOOLS
# 6504                                   BN Mi Banco            BUSINESS
# 4372                                      m-Faisaa             FINANCE
# 6148  BG video - floating video - background video       VIDEO_PLAYERS
# 2610                                      Snapchat              SOCIAL
# 6605                                         MI-BP  HEALTH_AND_FITNESS
# 2850                                   Open Camera         PHOTOGRAPHY
# 8808                        MegaNDS (NDS Emulator)                GAME
# 9270                                  My EF Center              FAMILY
# 5649                            Undertale AU Amino              SOCIAL
#
#       Rating   Reviews                Size   Installs  Type Price  \
# 9793     4.1       278                2.8M     100000  Free     0
# 6504     3.0       597                 17M     100000  Free     0
# 4372     4.0       142                6.2M      10000  Free     0
# 6148     4.1        64                2.0M       5000  Free     0
# 2610     4.0  17015352  Varies with device  500000000  Free     0
# 6605     5.0         1                 12M         50  Free     0
# 2850     4.3    116880                2.0M   10000000  Free     0
# 8808     3.4      2218                 11M     500000  Free     0
# 9270     2.8        89                 35M      10000  Free     0
# 5649     4.8      5369                 63M      50000  Free     0
#
#      Content Rating                   Genres      Last Updated  \
# 9793       Everyone                    Tools      July 2, 2018
# 6504       Everyone                 Business     July 12, 2018
# 4372       Everyone                  Finance     July 13, 2018
# 6148       Everyone  Video Players & Editors      May 21, 2018
# 2610           Teen                   Social     July 30, 2018
# 6605       Everyone         Health & Fitness     April 9, 2018
# 2850       Everyone              Photography    April 23, 2018
# 8808       Everyone                   Arcade  October 18, 2017
# 9270       Everyone                Education     July 23, 2018
# 5649           Teen                   Social     July 13, 2018
#
#              Current Ver         Android Ver
# 9793               3.1.5          4.0 and up
# 6504                 9.0          5.0 and up
# 4372                 5.3        4.0.3 and up
# 6148                 2.0          4.0 and up
# 2610  Varies with device  Varies with device
# 6605           1.0.8.506          5.0 and up
# 2850              1.43.3        4.0.3 and up
# 8808                 2.0          4.0 and up
# 9270              1.10.0          4.4 and up
# 5649           1.8.19106        4.0.3 and up

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  object
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.2+ MB

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ### 3.Check summary statistics of the dataset. List out the columns that need to be worked upon for model building.

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
#          Type  Price Content Rating Genres    Last Updated  \
# count   10840  10841          10840  10841           10841
# unique      3     93              6    120            1378
# top      Free      0       Everyone  Tools  August 3, 2018
# freq    10039  10040           8714    842             326
# mean      NaN    NaN            NaN    NaN             NaN
# std       NaN    NaN            NaN    NaN             NaN
# min       NaN    NaN            NaN    NaN             NaN
# 25%       NaN    NaN            NaN    NaN             NaN
# 50%       NaN    NaN            NaN    NaN             NaN
# 75%       NaN    NaN            NaN    NaN             NaN
# max       NaN    NaN            NaN    NaN             NaN
#
#                Current Ver Android Ver
# count                10833       10838
# unique                2832          33
# top     Varies with device  4.1 and up
# freq                  1459        2451
# mean                   NaN         NaN
# std                    NaN         NaN
# min                    NaN         NaN
# 25%                    NaN         NaN
# 50%                    NaN         NaN
# 75%                    NaN         NaN
# max                    NaN         NaN

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# ### 4.Check if there are any duplicate records in the dataset? if any drop them.

# %%
df.duplicated().sum()
# Out:
# 483

# %%
len(df[df.duplicated()])
# Out:
# 483

# %%
df.drop_duplicates(inplace=True)

# %%
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# ### 5.Check the unique categories of the column 'Category', Is there any invalid category? If yes, drop them.

# %%
df.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
invalid = df[df["Category"] == "1.9"]
invalid
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.drop(10472,inplace=True)

# %% [markdown]
# ### 6.Check if there are missing values present in the column Rating, If any? drop them and and create a new column as 'Rating_category' by converting ratings to high and low categories(>3.5 is high rest low)

# %%
z=df[df["Rating"].isna()].index
z
# Out:
# Int64Index([   23,   113,   123,   126,   129,   130,   134,   163,   180,
#               185,
#             ...
#             10816, 10818, 10821, 10822, 10823, 10824, 10825, 10831, 10835,
#             10838],
#            dtype='int64', length=1465)

# %%
df.drop(z,inplace=True)

# %%
def Rating_category(value):
    if value <= 3.5:
        return "Low"
    elif value > 3.5:
        return "High"

# %%
df["Rating_category"] = df['Rating'].map(Rating_category)

# %%
df.head(50)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# 12                     Tattoo Name On My Photo Editor     ART_AND_DESIGN
# 13                              Mandala Coloring Book     ART_AND_DESIGN
# 14    3D Color Pixel by Number - Sandbox Art Coloring     ART_AND_DESIGN
# 15                    Learn To Draw Kawaii Characters     ART_AND_DESIGN
# 16       Photo Designer - Write your name with shapes     ART_AND_DESIGN
# 17                           350 Diy Room Decor Ideas     ART_AND_DESIGN
# 18                      FlipaClip - Cartoon animation     ART_AND_DESIGN
# 19                                       ibis Paint X     ART_AND_DESIGN
# 20                        Logo Maker - Small Business     ART_AND_DESIGN
# 21          Boys Photo Editor - Six Pack & Men's Suit     ART_AND_DESIGN
# 22            Superheroes Wallpapers | 4K Backgrounds     ART_AND_DESIGN
# 24                        HD Mickey Minnie Wallpapers     ART_AND_DESIGN
# 25                         Harley Quinn wallpapers HD     ART_AND_DESIGN
# 26                      Colorfit - Drawing & Coloring     ART_AND_DESIGN
# 27                              Animated Photo Editor     ART_AND_DESIGN
# 28                              Pencil Sketch Drawing     ART_AND_DESIGN
# 29                    Easy Realistic Drawing Tutorial     ART_AND_DESIGN
# 30                     Pink Silver Bow Keyboard Theme     ART_AND_DESIGN
# 31                                  Art Drawing Ideas     ART_AND_DESIGN
# 32                          Anime Manga Coloring Book     ART_AND_DESIGN
# 33                                 Easy Origami Ideas     ART_AND_DESIGN
# 34                                    I Creative Idea     ART_AND_DESIGN
# 35                   How to draw Ladybug and Cat Noir     ART_AND_DESIGN
# 36     UNICORN - Color By Number & Pixel Art Coloring     ART_AND_DESIGN
# 37                                 Floor Plan Creator     ART_AND_DESIGN
# 38                     PIP Camera - PIP Collage Maker     ART_AND_DESIGN
# 39      How To Color Disney Princess - Coloring Pages     ART_AND_DESIGN
# 40                      Drawing Clothes Fashion Ideas     ART_AND_DESIGN
# 41                       Sad Poetry Photo Frames 2018     ART_AND_DESIGN
# 42                         Textgram - write on photos     ART_AND_DESIGN
# 43                                      Paint Splash!     ART_AND_DESIGN
# 44        Popsicle Sticks and Similar DIY Craft Ideas     ART_AND_DESIGN
# 45  Canva: Poster, banner, card maker & graphic de...     ART_AND_DESIGN
# 46  Install images with music to make video withou...     ART_AND_DESIGN
# 47              Little Teddy Bear Colouring Book Game     ART_AND_DESIGN
# 48                                   How To Draw Food     ART_AND_DESIGN
# 49                        Monster Truck Stunt 3D 2019  AUTO_AND_VEHICLES
# 50                               Real Tractor Farming  AUTO_AND_VEHICLES
#
#     Rating Reviews                Size     Installs  Type Price  \
# 0      4.1     159                 19M      10,000+  Free     0
# 1      3.9     967                 14M     500,000+  Free     0
# 2      4.7   87510                8.7M   5,000,000+  Free     0
# 3      4.5  215644                 25M  50,000,000+  Free     0
# 4      4.3     967                2.8M     100,000+  Free     0
# 5      4.4     167                5.6M      50,000+  Free     0
# 6      3.8     178                 19M      50,000+  Free     0
# 7      4.1   36815                 29M   1,000,000+  Free     0
# 8      4.4   13791                 33M   1,000,000+  Free     0
# 9      4.7     121                3.1M      10,000+  Free     0
# 10     4.4   13880                 28M   1,000,000+  Free     0
# 11     4.4    8788                 12M   1,000,000+  Free     0
# 12     4.2   44829                 20M  10,000,000+  Free     0
# 13     4.6    4326                 21M     100,000+  Free     0
# 14     4.4    1518                 37M     100,000+  Free     0
# 15     3.2      55                2.7M       5,000+  Free     0
# 16     4.7    3632                5.5M     500,000+  Free     0
# 17     4.5      27                 17M      10,000+  Free     0
# 18     4.3  194216                 39M   5,000,000+  Free     0
# 19     4.6  224399                 31M  10,000,000+  Free     0
# 20     4.0     450                 14M     100,000+  Free     0
# 21     4.1     654                 12M     100,000+  Free     0
# 22     4.7    7699                4.2M     500,000+  Free     0
# 24     4.7     118                 23M      50,000+  Free     0
# 25     4.8     192                6.0M      10,000+  Free     0
# 26     4.7   20260                 25M     500,000+  Free     0
# 27     4.1     203                6.1M     100,000+  Free     0
# 28     3.9     136                4.6M      10,000+  Free     0
# 29     4.1     223                4.2M     100,000+  Free     0
# 30     4.2    1120                9.2M     100,000+  Free     0
# 31     4.1     227                5.2M      50,000+  Free     0
# 32     4.5    5035                 11M     100,000+  Free     0
# 33     4.2    1015                 11M     100,000+  Free     0
# 34     4.7     353                4.2M      10,000+  Free     0
# 35     3.8     564                9.2M     100,000+  Free     0
# 36     4.7    8145                 24M     500,000+  Free     0
# 37     4.1   36639  Varies with device   5,000,000+  Free     0
# 38     4.7     158                 11M      10,000+  Free     0
# 39     4.0     591                9.4M     500,000+  Free     0
# 40     4.2     117                 15M      10,000+  Free     0
# 41     4.5     176                 10M     100,000+  Free     0
# 42     4.4  295221  Varies with device  10,000,000+  Free     0
# 43     3.8    2206                1.2M     100,000+  Free     0
# 44     4.2      26                 12M      10,000+  Free     0
# 45     4.7  174531                 24M  10,000,000+  Free     0
# 46     4.6    1070                 26M     100,000+  Free     0
# 47     4.2      85                8.0M     100,000+  Free     0
# 48     4.3     845                7.9M     100,000+  Free     0
# 49     4.2     367                 25M     100,000+  Free     0
# 50     4.0    1598                 56M   1,000,000+  Free     0
#
#    Content Rating                     Genres        Last Updated  \
# 0        Everyone               Art & Design     January 7, 2018
# 1        Everyone  Art & Design;Pretend Play    January 15, 2018
# 2        Everyone               Art & Design      August 1, 2018
# 3            Teen               Art & Design        June 8, 2018
# 4        Everyone    Art & Design;Creativity       June 20, 2018
# 5        Everyone               Art & Design      March 26, 2017
# 6        Everyone               Art & Design      April 26, 2018
# 7        Everyone               Art & Design       June 14, 2018
# 8        Everyone               Art & Design  September 20, 2017
# 9        Everyone    Art & Design;Creativity        July 3, 2018
# 10       Everyone               Art & Design    October 27, 2017
# 11       Everyone               Art & Design       July 31, 2018
# 12           Teen               Art & Design       April 2, 2018
# 13       Everyone               Art & Design       June 26, 2018
# 14       Everyone               Art & Design      August 3, 2018
# 15       Everyone               Art & Design        June 6, 2018
# 16       Everyone               Art & Design       July 31, 2018
# 17       Everyone               Art & Design    November 7, 2017
# 18       Everyone               Art & Design      August 3, 2018
# 19       Everyone               Art & Design       July 30, 2018
# 20       Everyone               Art & Design      April 20, 2018
# 21       Everyone               Art & Design      March 20, 2018
# 22   Everyone 10+               Art & Design       July 12, 2018
# 24       Everyone               Art & Design        July 7, 2018
# 25       Everyone               Art & Design      April 25, 2018
# 26       Everyone    Art & Design;Creativity    October 11, 2017
# 27       Everyone               Art & Design      March 21, 2018
# 28       Everyone               Art & Design       July 12, 2018
# 29       Everyone               Art & Design     August 22, 2017
# 30       Everyone               Art & Design       July 12, 2018
# 31       Everyone               Art & Design        May 31, 2018
# 32       Everyone               Art & Design       July 19, 2018
# 33       Everyone               Art & Design     January 6, 2018
# 34           Teen               Art & Design      April 27, 2018
# 35       Everyone               Art & Design       July 11, 2018
# 36       Everyone    Art & Design;Creativity      August 2, 2018
# 37       Everyone               Art & Design       July 14, 2018
# 38       Everyone               Art & Design   November 29, 2017
# 39       Everyone               Art & Design      March 31, 2018
# 40       Everyone               Art & Design       July 20, 2018
# 41       Everyone               Art & Design       April 2, 2018
# 42       Everyone               Art & Design       July 30, 2018
# 43       Everyone    Art & Design;Creativity      April 15, 2018
# 44       Everyone               Art & Design     January 3, 2018
# 45       Everyone               Art & Design       July 31, 2018
# 46       Everyone               Art & Design   November 14, 2017
# 47       Everyone               Art & Design   December 17, 2017
# 48       Everyone               Art & Design        May 28, 2018
# 49       Everyone            Auto & Vehicles        May 10, 2018
# 50       Everyone            Auto & Vehicles       July 26, 2018
#
#            Current Ver         Android Ver Rating_category
# 0                1.0.0        4.0.3 and up            High
# 1                2.0.0        4.0.3 and up            High
# 2                1.2.4        4.0.3 and up            High
# 3   Varies with device          4.2 and up            High
# 4                  1.1          4.4 and up            High
# 5                  1.0          2.3 and up            High
# 6                  1.1        4.0.3 and up            High
# 7             6.1.61.1          4.2 and up            High
# 8                2.9.2          3.0 and up            High
# 9                  2.8        4.0.3 and up            High
# 10               1.0.4          4.1 and up            High
# 11              1.0.15          4.0 and up            High
# 12                 3.8          4.1 and up            High
# 13               1.0.4          4.4 and up            High
# 14               1.2.3          2.3 and up            High
# 15                 NaN          4.2 and up             Low
# 16                 3.1          4.1 and up            High
# 17                 1.0          2.3 and up            High
# 18               2.2.5        4.0.3 and up            High
# 19               5.5.4          4.1 and up            High
# 20                 4.0          4.1 and up            High
# 21                 1.1        4.0.3 and up            High
# 22             2.2.6.2        4.0.3 and up            High
# 24               1.1.3          4.1 and up            High
# 25                 1.5          3.0 and up            High
# 26               1.0.8        4.0.3 and up            High
# 27                1.03        4.0.3 and up            High
# 28                 6.0          2.3 and up            High
# 29                 1.0          2.3 and up            High
# 30         6.7.12.2018        4.0.3 and up            High
# 31                 1.2          2.3 and up            High
# 32                2.20          4.0 and up            High
# 33               1.1.0          4.1 and up            High
# 34                 1.6          4.1 and up            High
# 35                 2.1          4.1 and up            High
# 36               1.0.9          4.4 and up            High
# 37  Varies with device        2.3.3 and up            High
# 38                 1.3        4.0.3 and up            High
# 39                   1          4.0 and up            High
# 40               2.0.1        4.0.3 and up            High
# 41                 1.0        4.0.3 and up            High
# 42  Varies with device  Varies with device            High
# 43                1.46          4.1 and up            High
# 44               1.0.0          4.1 and up            High
# 45               1.6.1          4.1 and up            High
# 46                 1.6          4.1 and up            High
# 47               2.0.0          4.1 and up            High
# 48                 1.0          2.3 and up            High
# 49                 1.0        4.0.3 and up            High
# 50                11.0          4.1 and up            High

# %% [markdown]
# ### 7.Check the distribution of the newly created column 'Rating_category' and comment on the distribution.

# %%
df["Rating_category"].value_counts()
# Out:
# High    8012
# Low      880
# Name: Rating_category, dtype: int64

# %% [markdown]
# ### 8.Convert the column "Reviews'' to numeric data type and check the presence of outliers in the column and handle the outliers using a transformation approach.

# %%
# df["Reviews"].astype(str).astype(int)
df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

# %%
df["Reviews"].dtypes
# Out:
# dtype('int64')

# %%
sns.boxplot(df["Reviews"])
# Out:
# <Axes: >

# %%
log10 = np.log10(df["Reviews"])
sns.boxplot(log10, color="violet" , showmeans = True)
# Out:
# <Axes: >

# %% [markdown]
# ### 9.The column 'Size' contains alphanumeric values, treat the non numeric data and convert the column into suitable data type.

# %%
df["Size"].head(50)
# Out:
# 0                    19M
# 1                    14M
# 2                   8.7M
# 3                    25M
# 4                   2.8M
# 5                   5.6M
# 6                    19M
# 7                    29M
# 8                    33M
# 9                   3.1M
# 10                   28M
# 11                   12M
# 12                   20M
# 13                   21M
# 14                   37M
# 15                  2.7M
# 16                  5.5M
# 17                   17M
# 18                   39M
# 19                   31M
# 20                   14M
# 21                   12M
# 22                  4.2M
# 24                   23M
# 25                  6.0M
# 26                   25M
# 27                  6.1M
# 28                  4.6M
# 29                  4.2M
# 30                  9.2M
# 31                  5.2M
# 32                   11M
# 33                   11M
# 34                  4.2M
# 35                  9.2M
# 36                   24M
# 37    Varies with device
# 38                   11M
# 39                  9.4M
# 40                   15M
# 41                   10M
# 42    Varies with device
# 43                  1.2M
# 44                   12M
# 45                   24M
# 46                   26M
# 47                  8.0M
# 48                  7.9M
# 49                   25M
# 50                   56M
# Name: Size, dtype: object

# %%
df["Size"] = df["Size"].apply(lambda x : x.replace(",",""))
df["Size"] = df["Size"].str.replace("M","000000")
df["Size"] = df["Size"].str.replace("k","000")
# Finding the idexes of records having Size "Varies_with_device".
Varies_with_device = df[df["Size"] == "Varies with device"].index
df.drop(Varies_with_device,inplace=True)

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Size'] = pd.to_numeric(df['Size'], errors='coerce')

# %%
df.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size               float64
# Installs             int64
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %% [markdown]
# ### 10. Check the column 'Installs', treat the unwanted characters and convert the column into a suitable data type.

# %%
df['Installs'].value_counts()
# Out:
# 1000000       1230
# 100000        1003
# 10000          949
# 10000000       762
# 1000           675
# 5000000        493
# 500000         471
# 50000          432
# 5000           414
# 100            297
# 500            195
# 100000000      192
# 50000000       144
# 10              67
# 50              56
# 500000000       24
# 5                9
# 1000000000       8
# 1                3
# Name: Installs, dtype: int64

# %%
df=df.drop(10472)

# %%
df[df['Installs']=="Free"]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df['Installs'].value_counts()
# Out:
# 1,000,000        1579
# 10,000,000       1252
# 100,000          1169
# 10,000           1054
# 1,000             907
# 5,000,000         752
# 100               719
# 500,000           539
# 50,000            479
# 5,000             477
# 100,000,000       409
# 10                386
# 500               330
# 50,000,000        289
# 50                205
# 5                  82
# 500,000,000        72
# 1                  67
# 1,000,000,000      58
# 0                  15
# Name: Installs, dtype: int64

# %%
df["Installs"] = df["Installs"].str.replace("+","").replace(","," ")
# Out:
# C:\Users\pranitha\AppData\Local\Temp\ipykernel_11120\1730774547.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Installs"] = df["Installs"].str.replace("+","").replace(","," ")

# %%
df["Installs"] = df["Installs"].str.replace("m","")

# %%
df["Installs"] = pd.to_numeric(df["Installs"], errors='coerce')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews        Size  Installs  Type  Price Content Rating  \
# 0         4.1      159  19000000.0     10000  Free    0.0       Everyone
# 1         3.9      967  14000000.0    500000  Free    0.0       Everyone
# 2         4.7    87510         8.7   5000000  Free    0.0       Everyone
# 3         4.5   215644  25000000.0  50000000  Free    0.0           Teen
# 4         4.3      967         2.8    100000  Free    0.0       Everyone
# ...       ...      ...         ...       ...   ...    ...            ...
# 10833     4.8       44    619000.0      1000  Free    0.0       Everyone
# 10834     4.0        7         2.6       500  Free    0.0       Everyone
# 10836     4.5       38  53000000.0      5000  Free    0.0       Everyone
# 10837     5.0        4         3.6       100  Free    0.0       Everyone
# 10840     4.5   398307  19000000.0  10000000  Free    0.0       Everyone
#
#                           Genres      Last Updated         Current Ver  \
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
# ...                          ...               ...                 ...
# 10833          Books & Reference    March 23, 2014                 0.8
# 10834                  Education     June 18, 2017               1.0.0
# 10836                  Education     July 25, 2017                1.48
# 10837                  Education      July 6, 2018                 1.0
# 10840                  Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver Rating_category
# 0            4.0.3 and up            High
# 1            4.0.3 and up            High
# 2            4.0.3 and up            High
# 3              4.2 and up            High
# 4              4.4 and up            High
# ...                   ...             ...
# 10833          2.2 and up            High
# 10834          4.1 and up            High
# 10836          4.1 and up            High
# 10837          4.1 and up            High
# 10840  Varies with device            High
#
# [7424 rows x 14 columns]

# %%
df.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size               float64
# Installs             int64
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %% [markdown]
# ### 11. Check the column 'Price' , remove the unwanted characters and convert the column into a suitable data type.

# %%
df["Price"] = df["Price"].apply(lambda x : x.replace(",",""))
df["Price"] = df["Price"].str.replace("$", "")
df["Price"] = pd.to_numeric(df["Price"], errors='coerce')
# Out:
# C:\Users\pranitha\AppData\Local\Temp\ipykernel_11120\3843464808.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Price"] = df["Price"].str.replace("$", "")

# %%
df.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size               float64
# Installs             int64
# Type                object
# Price              float64
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %% [markdown]
# ### 12. Drop the columns which you think redundant for the analysis.

# %%
df.columns
df.drop(["App","Rating","Genres","Last Updated","Current Ver","Android Ver"], axis = 1,inplace = True)

# %% [markdown]
# ### 13. Encode the categorical columns

# %%
df
# Out:
#                   Category  Reviews        Size  Installs  Type  Price  \
# 0           ART_AND_DESIGN      159  19000000.0     10000  Free    0.0
# 1           ART_AND_DESIGN      967  14000000.0    500000  Free    0.0
# 2           ART_AND_DESIGN    87510         8.7   5000000  Free    0.0
# 3           ART_AND_DESIGN   215644  25000000.0  50000000  Free    0.0
# 4           ART_AND_DESIGN      967         2.8    100000  Free    0.0
# ...                    ...      ...         ...       ...   ...    ...
# 10833  BOOKS_AND_REFERENCE       44    619000.0      1000  Free    0.0
# 10834               FAMILY        7         2.6       500  Free    0.0
# 10836               FAMILY       38  53000000.0      5000  Free    0.0
# 10837               FAMILY        4         3.6       100  Free    0.0
# 10840            LIFESTYLE   398307  19000000.0  10000000  Free    0.0
#
#       Content Rating Rating_category
# 0           Everyone            High
# 1           Everyone            High
# 2           Everyone            High
# 3               Teen            High
# 4           Everyone            High
# ...              ...             ...
# 10833       Everyone            High
# 10834       Everyone            High
# 10836       Everyone            High
# 10837       Everyone            High
# 10840       Everyone            High
#
# [7424 rows x 8 columns]

# %%
labelencoder = LabelEncoder()
df["Category"] = labelencoder.fit_transform(df["Category"])
df.head(10)
# Out:
#    Category  Reviews        Size  Installs  Type  Price Content Rating  \
# 0         0      159  19000000.0     10000  Free    0.0       Everyone
# 1         0      967  14000000.0    500000  Free    0.0       Everyone
# 2         0    87510         8.7   5000000  Free    0.0       Everyone
# 3         0   215644  25000000.0  50000000  Free    0.0           Teen
# 4         0      967         2.8    100000  Free    0.0       Everyone
# 5         0      167         5.6     50000  Free    0.0       Everyone
# 6         0      178  19000000.0     50000  Free    0.0       Everyone
# 7         0    36815  29000000.0   1000000  Free    0.0       Everyone
# 8         0    13791  33000000.0   1000000  Free    0.0       Everyone
# 9         0      121         3.1     10000  Free    0.0       Everyone
#
#   Rating_category
# 0            High
# 1            High
# 2            High
# 3            High
# 4            High
# 5            High
# 6            High
# 7            High
# 8            High
# 9            High

# %%
df["Content Rating"] = labelencoder.fit_transform(df["Content Rating"])
df["Content Rating"].value_counts()
# Out:
# 1    5958
# 4     832
# 3     332
# 2     299
# 0       2
# 5       1
# Name: Content Rating, dtype: int64

# %%
df["Type"] = labelencoder.fit_transform(df["Type"])
df["Type"].value_counts()
# Out:
# 0    6877
# 1     547
# Name: Type, dtype: int64

# %%
df["Rating_category"] = labelencoder.fit_transform(df["Rating_category"])
df["Rating_category"].value_counts()
# Out:
# 0    6599
# 1     825
# Name: Rating_category, dtype: int64

# %%
df
# Out:
#        Category  Reviews        Size  Installs  Type  Price  Content Rating  \
# 0             0      159  19000000.0     10000     0    0.0               1
# 1             0      967  14000000.0    500000     0    0.0               1
# 2             0    87510         8.7   5000000     0    0.0               1
# 3             0   215644  25000000.0  50000000     0    0.0               4
# 4             0      967         2.8    100000     0    0.0               1
# ...         ...      ...         ...       ...   ...    ...             ...
# 10833         3       44    619000.0      1000     0    0.0               1
# 10834        11        7         2.6       500     0    0.0               1
# 10836        11       38  53000000.0      5000     0    0.0               1
# 10837        11        4         3.6       100     0    0.0               1
# 10840        18   398307  19000000.0  10000000     0    0.0               1
#
#        Rating_category
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 10833                0
# 10834                0
# 10836                0
# 10837                0
# 10840                0
#
# [7424 rows x 8 columns]

# %% [markdown]
# ### 14. Segregate the target and independent features

# %%
df
# Out:
#        Category  Reviews        Size  Installs  Type  Price  Content Rating  \
# 0             0      159  19000000.0     10000     0    0.0               1
# 1             0      967  14000000.0    500000     0    0.0               1
# 2             0    87510         8.7   5000000     0    0.0               1
# 3             0   215644  25000000.0  50000000     0    0.0               4
# 4             0      967         2.8    100000     0    0.0               1
# ...         ...      ...         ...       ...   ...    ...             ...
# 10833         3       44    619000.0      1000     0    0.0               1
# 10834        11        7         2.6       500     0    0.0               1
# 10836        11       38  53000000.0      5000     0    0.0               1
# 10837        11        4         3.6       100     0    0.0               1
# 10840        18   398307  19000000.0  10000000     0    0.0               1
#
#        Rating_category
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 10833                0
# 10834                0
# 10836                0
# 10837                0
# 10840                0
#
# [7424 rows x 8 columns]

# %%
X= df.drop('Rating_category', axis=1)
Y= df[["Rating_category"]]

# %%
Y
# Out:
#        Rating_category
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 10833                0
# 10834                0
# 10836                0
# 10837                0
# 10840                0
#
# [7424 rows x 1 columns]

# %%
X
# Out:
#        Category  Reviews        Size  Installs  Type  Price  Content Rating
# 0             0      159  19000000.0     10000     0    0.0               1
# 1             0      967  14000000.0    500000     0    0.0               1
# 2             0    87510         8.7   5000000     0    0.0               1
# 3             0   215644  25000000.0  50000000     0    0.0               4
# 4             0      967         2.8    100000     0    0.0               1
# ...         ...      ...         ...       ...   ...    ...             ...
# 10833         3       44    619000.0      1000     0    0.0               1
# 10834        11        7         2.6       500     0    0.0               1
# 10836        11       38  53000000.0      5000     0    0.0               1
# 10837        11        4         3.6       100     0    0.0               1
# 10840        18   398307  19000000.0  10000000     0    0.0               1
#
# [7424 rows x 7 columns]

# %% [markdown]
# ### 15.Split the dataset into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30 , random_state=1)

# %% [markdown]
# ### 16.Standardize the data, so that the values are within a particular range

# %%
from sklearn.preprocessing import StandardScaler

# %%
df
# Out:
#        Category  Reviews        Size  Installs  Type  Price  Content Rating  \
# 0             0      159  19000000.0     10000     0    0.0               1
# 1             0      967  14000000.0    500000     0    0.0               1
# 2             0    87510         8.7   5000000     0    0.0               1
# 3             0   215644  25000000.0  50000000     0    0.0               4
# 4             0      967         2.8    100000     0    0.0               1
# ...         ...      ...         ...       ...   ...    ...             ...
# 10833         3       44    619000.0      1000     0    0.0               1
# 10834        11        7         2.6       500     0    0.0               1
# 10836        11       38  53000000.0      5000     0    0.0               1
# 10837        11        4         3.6       100     0    0.0               1
# 10840        18   398307  19000000.0  10000000     0    0.0               1
#
#        Rating_category
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 10833                0
# 10834                0
# 10836                0
# 10837                0
# 10840                0
#
# [7424 rows x 8 columns]

# %%
scaler = StandardScaler()
df= scaler.fit_transform(df)

# %%
df
# Out:
# array([[-2.03766618, -0.15980174, -0.07422317, ..., -0.06305842,
#         -0.46322046, -0.35358018],
#        [-2.03766618, -0.15933831, -0.27499084, ..., -0.06305842,
#         -0.46322046, -0.35358018],
#        [-2.03766618, -0.10970091, -0.83713998, ..., -0.06305842,
#         -0.46322046, -0.35358018],
#        ...,
#        [-0.68621673, -0.15987115,  1.29099702, ..., -0.06305842,
#         -0.46322046, -0.35358018],
#        [-0.68621673, -0.15989065, -0.83714018, ..., -0.06305842,
#         -0.46322046, -0.35358018],
#        [ 0.17379656,  0.06855908, -0.07422317, ..., -0.06305842,
#         -0.46322046, -0.35358018]])

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#              0         1         2         3         4         5         6  \
# 0    -2.037666 -0.159802 -0.074223 -0.168764 -0.282029 -0.063058 -0.463220
# 1    -2.037666 -0.159338 -0.274991 -0.158181 -0.282029 -0.063058 -0.463220
# 2    -2.037666 -0.109701 -0.837140 -0.060990 -0.282029 -0.063058 -0.463220
# 3    -2.037666 -0.036209  0.166698  0.910911 -0.282029 -0.063058  2.517665
# 4    -2.037666 -0.159338 -0.837140 -0.166820 -0.282029 -0.063058 -0.463220
# ...        ...       ...       ...       ...       ...       ...       ...
# 7419 -1.669089 -0.159868 -0.812285 -0.168958 -0.282029 -0.063058 -0.463220
# 7420 -0.686217 -0.159889 -0.837140 -0.168969 -0.282029 -0.063058 -0.463220
# 7421 -0.686217 -0.159871  1.290997 -0.168872 -0.282029 -0.063058 -0.463220
# 7422 -0.686217 -0.159891 -0.837140 -0.168977 -0.282029 -0.063058 -0.463220
# 7423  0.173797  0.068559 -0.074223  0.046999 -0.282029 -0.063058 -0.463220
#
#             7
# 0    -0.35358
# 1    -0.35358
# 2    -0.35358
# 3    -0.35358
# 4    -0.35358
# ...       ...
# 7419 -0.35358
# 7420 -0.35358
# 7421 -0.35358
# 7422 -0.35358
# 7423 -0.35358
#
# [7424 rows x 8 columns]
